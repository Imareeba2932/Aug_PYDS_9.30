# %%
import math

# %%
print(math.sqrt(13))
print(math.factorial(5))
print(math.log(100,10))
print(math.log(100,2))
print(math.gcd(12,18,14))
print(math.lcm(12,18,14))
print(math.pi)
print(math.e)
print(math.sin(3))
# Out:
# 3.605551275463989
# 120
# 2.0
# 6.643856189774725
# 2
# 252
# 3.141592653589793
# 2.718281828459045
# 0.1411200080598672

# %%
from random import random, randint, choice, shuffle

# %%
print('get a random number between 0 and 1:', random())
print('get a random number between 1 and 10:', randint(1,10))
print('Select a random item',choice(['win','lose','draw']))
names=['John','Jane','Jack','Jill','Joe']
shuffle(names)
print('shuffle a list',names)
# Out:
# get a random number between 0 and 1: 0.3885518933228881
# get a random number between 1 and 10: 2
# Select a random item win
# shuffle a list ['Jill', 'Jack', 'Jane', 'Joe', 'John']

# %%
from datetime import datetime as dt

# %%
print('current :', dt.now())
# Out:
# current : 2023-09-15 12:47:26.360718

# %%
print('current date :', dt.now().date())
print('current time :', dt.now().time())
# Out:
# current date : 2023-09-15
# current time : 12:47:26.378876

# %%
print('current year:', dt.now().year)
print('current month:', dt.now().month)
print('current day:', dt.now().day)
print('current hour:', dt.now().hour)
print('current minute:', dt.now().minute)
print('current second:', dt.now().second)
print('current weekday:', dt.now().weekday())
# Out:
# current year: 2023
# current month: 9
# current day: 15
# current hour: 12
# current minute: 47
# current second: 26
# current weekday: 4

# %%
date = dt.strftime(dt.now(), '%d/%m/%y')
print('formatted date:', date)
# Out:
# formatted date: 15/09/23

# %%
time = dt.strftime(dt.now(), '%H:%M:%S')
print('formatted time:', time)
# Out:
# formatted time: 12:47:26

# %%
import os #know about folder, files or directories

# %%
print('Current Folder', os.getcwd())
# Out:
# Current Folder c:\Users\LENOVO\Documents\Aug_PYDS_9.30

# %%
files = os.listdir() #list all files and folders of current working directory
print(files)
# Out:
# ['.git', 'classes.ipynb', 'conditions.ipynb', 'conditions2.ipynb', 'datatypes.ipynb', 'dictionary.ipynb', 'functions.ipynb', 'Introduction.ipynb', 'libraries.ipynb', 'list.ipynb', 'listcomprehension.ipynb', 'loops.ipynb', 'operators.ipynb', 'p2.py', 'pattern1.py', 'pattern2.py', 'pythagorus.py', 'quiz.ipynb', 'string.ipynb', 'variabl.ipynb']

# %%
files=os.listdir(r"C:\Users\LENOVO\Documents\Analysis-of-Road-Accidents")
print(files)
print(len(files))
# Out:
# ['.git', 'analysis.ipynb', 'analysis2.ipynb', 'analysis3.ipynb', 'analysis4.ipynb', 'analysis5.ipynb', 'dataset', 'project.py', 'readme.md', 'requirements.txt', 'static', 'templates']
# 12

# %%
os.walk('C:') #walk through all folders and files
# Out:
# <generator object _walk at 0x00000230AC9039C0>

# %%
total_files=0
for path, folders, files in os.walk(r"C:\Users\LENOVO\Documents\DP-2023-MAY-MERN-02-00-MTWF"):
    print('=>', path)
    print('📁', folders)
    print('📄', files)
    total_files += len(files)
print('Total files:', total_files)
# Out:
# => C:\Users\LENOVO\Documents\DP-2023-MAY-MERN-02-00-MTWF
# 📁 ['.git', 'Assignments', 'Section 1', 'Section 2', 'Section 3']
# 📄 ['bootstrap_task.png']
# => C:\Users\LENOVO\Documents\DP-2023-MAY-MERN-02-00-MTWF\.git
# 📁 ['hooks', 'info', 'logs', 'objects', 'refs']
# 📄 ['config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'packed-refs']
# => C:\Users\LENOVO\Documents\DP-2023-MAY-MERN-02-00-MTWF\.git\hooks
# 📁 []
# 📄 ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'update.sample']
# => C:\Users\LENOVO\Documents\DP-2023-MAY-MERN-02-00-MTWF\.git\info
# 📁 []
# 📄 ['exclude']
# => C:\Users\LENOVO\Documents\DP-2023-MAY-MERN-02-00-MTWF\.git\logs
# 📁 ['refs']
# 📄 ['HEAD']
# => C:\Users\LENOVO\Documents\DP-2023-MAY-MERN-02-00-MTWF\.git\logs\refs
# ...

# %%
files=r'C:\Users\LENOVO\Documents\DP-2023-MAY-MERN-02-00-MTWF'
if os.path.exists(files):
    print("file exist")
# Out:
# file exist

# %%
file=r"C:\Users\LENOVO\Documents\DP-2023-MAY-MERN-02-00-MTWF"
if os.path.exists(file):
    print("file exist")
    size=os.path.getsize(file)
    print('size in bytes:', size)
    print('size in kilobytes:', size/1024) 
    print('size in megabytes:', size/(1024*1024))
    print('size in gigabytes:', size/(1024*1024*1024))
    print('size in terabytes:', size/(1024*1024*1024*1024))
# Out:
# file exist
# size in bytes: 4096
# size in kilobytes: 4.0
# size in megabytes: 0.00390625
# size in gigabytes: 3.814697265625e-06
# size in terabytes: 3.725290298461914e-09

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('Canada.xlsx')
df.head()
# Out:
#             Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                  NaN        NaN        NaN        NaN        NaN        NaN
# 1                  NaN        NaN        NaN        NaN        NaN        NaN
# 2                  NaN        NaN        NaN        NaN        NaN        NaN
# 3       United Nations        NaN        NaN        NaN        NaN        NaN
# 4  Population Division        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 28 Unnamed: 29  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 4        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
# ...

# %%
df.tail()
# Out:
#     Unnamed: 0  Unnamed: 1     Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 44  Immigrants  Foreigners        Oceania   Melanesia        632        707
# 45  Immigrants  Foreigners        Oceania  Micronesia          1         ..
# 46  Immigrants  Foreigners        Oceania   Polynesia          5         13
# 47  Immigrants  Foreigners  Oceania Total         NaN       1942       1839
# 48  Immigrants  Foreigners        Unknown     Unknown      44000      18078
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 28 Unnamed: 29  \
# 44        816        558        391        448  ...         497         300
# 45         ..          1         ..         ..  ...           1           2
# 46         11          2          6          5  ...          10           4
# 47       1675       1018        878        920  ...        1788        1585
# 48      16904      13635      14855      14368  ...        3739        4785
#
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37']

# %%
df['Unnamed: 15']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19     1991
# 20        3
# 21     6535
# 22      328
# 23     4745
# 24      834
# 25     1786
# 26    14228
# 27       ..
# 28    17364
# 29    21294
# 30    32853
# 31    18453
# 32    89964
# 33    19753
# 34    24572
# 35     7804
# 36     5809
# 37    57938
# 38    12887
# 39    13474
# 40    10466
# 41    36827
# 42     6054
# 43      867
# 44     1621
# 45       ..
# 46        7
# 47     2495
# 48    25293
# Name: Unnamed: 15, dtype: object

# %%
df.iloc[2]
# Out:
# Unnamed: 0     NaN
# Unnamed: 1     NaN
# Unnamed: 2     NaN
# Unnamed: 3     NaN
# Unnamed: 4     NaN
# Unnamed: 5     NaN
# Unnamed: 6     NaN
# Unnamed: 7     NaN
# Unnamed: 8     NaN
# Unnamed: 9     NaN
# Unnamed: 10    NaN
# Unnamed: 11    NaN
# Unnamed: 12    NaN
# Unnamed: 13    NaN
# Unnamed: 14    NaN
# Unnamed: 15    NaN
# Unnamed: 16    NaN
# Unnamed: 17    NaN
# Unnamed: 18    NaN
# Unnamed: 19    NaN
# Unnamed: 20    NaN
# Unnamed: 21    NaN
# Unnamed: 22    NaN
# Unnamed: 23    NaN
# Unnamed: 24    NaN
# Unnamed: 25    NaN
# Unnamed: 26    NaN
# Unnamed: 27    NaN
# Unnamed: 28    NaN
# Unnamed: 29    NaN
# Unnamed: 30    NaN
# Unnamed: 31    NaN
# Unnamed: 32    NaN
# Unnamed: 33    NaN
# Unnamed: 34    NaN
# Unnamed: 35    NaN
# Unnamed: 36    NaN
# Unnamed: 37    NaN
# Name: 2, dtype: object

# %%
df.iloc[[0,5,2,6,4,8]]
# Out:
#                                   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                        NaN        NaN        NaN        NaN
# 5  Department of Economic and Social Affairs        NaN        NaN        NaN
# 2                                        NaN        NaN        NaN        NaN
# 6                                        NaN        NaN        NaN        NaN
# 4                        Population Division        NaN        NaN        NaN
# 8                                        NaN        NaN        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 5        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 2        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 6        NaN        NaN        NaN        NaN        NaN        NaN  ...
# ...

# %%
df.iloc[:,[0,2,5,7,10]] #all rows, columns 0,2,5,7,10
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                      United Nations
# 4                                 Population Division
# 5           Department of Economic and Social Affairs
# 6                                                 NaN
# 7   International Migration Flows to and from Sele...
# 8                                                 NaN
# 9                            POP/DB/MIG/Flow/Rev.2015
# 10  December 2015 - Copyright © 2015 by United Nat...
# 11  Suggested citation: United Nations, Department...
# 12   International Migration Flows to and from Sel...
# 13                                                NaN
# 14                                                NaN
# 15                          Reporting country: Canada
# ...

# %%
df.describe(exclude=np.number) #exclude numerical columns
# Out:
#         Unnamed: 0  Unnamed: 1 Unnamed: 2        Unnamed: 3 Unnamed: 4  \
# count           41          30         31                25         30
# unique          13           3         14                24         29
# top     Immigrants  Foreigners     Africa  Northern America         ..
# freq            29          28          5                 2          2
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# count          30         30         30         30         30  ...
# unique         28         28         29         28         28  ...
# top            ..         ..         ..         ..         ..  ...
# freq            3          3          2          3          3  ...
#
#        Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# count           30          30          30          30          30
# unique          30          30          30          30          29
# top           2002        2003        2004        2005           1
# ...

# %%
df[[1980,1981,1982,1983,1984,1985]].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\LENOVO\Documents\Aug_PYDS_9.30\analysis\preprocessing4.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/LENOVO/Documents/Aug_PYDS_9.30/analysis/preprocessing4.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> df[[1980,1981,1982,1983,1984,1985]].sum()
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
